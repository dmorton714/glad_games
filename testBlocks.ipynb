# %%
import random
import time
import os

# %% [markdown]
# # Welcome Section
#
# <pre>
# <b> _____ _           _ _       _               _____                           _</b>
# <b>|  __ \ |         | (_)     | |             |  __ \                         | |</b>
# <b>| |  \/ | __ _  __| |_  __ _| |_ ___  _ __  | |  \/ __ _ _ __ ___   ___  ___| |</b>
# <b>| | __| |/ _` |/ _` | |/ _` | __/ _ \| '__| | | __ / _` | '_ ` _ \ / _ \/ __| |</b>
# <b>| |_\ \ | (_| | (_| | | (_| | || (_) | |    | |_\ \ (_| | | | | | |  __/\__ \_|</b>
# <b>\_____/_|\__,_|\__,_|_|\__,_|\__\___/|_|     \____/\__,_|_| |_| |_|\___||___(_)</b>
# </pre>

# %%
def clear_screen():
    os.system("cls" if os.name == "nt" else "clear")

titleScreen = "Welcome to:\n\
\n  _____ _           _ _       _               _____                           _ \
\n |  __ \ |         | (_)     | |             |  __ \                         | | \
\n | |  \/ | __ _  __| |_  __ _| |_ ___  _ __  | |  \/ __ _ _ __ ___   ___  ___| | \
\n | | __| |/ _` |/ _` | |/ _` | __/ _ \| '__| | | __ / _` | '_ ` _ \ / _ \/ __| | \
\n | |_\ \ | (_| | (_| | | (_| | || (_) | |    | |_\ \ (_| | | | | | |  __/\__ \_| \
\n  \____/_|\__,_|\__,_|_|\__,_|\__\___/|_|     \____/\__,_|_| |_| |_|\___||___/(_)"

num_repetitions = 5

#  works as neeeded wont print in notebook correct 
# for _ in range(num_repetitions):
#     print(titleScreen)
#     time.sleep(0.25)
#     clear_screen()
#     time.sleep(0.125)

print(titleScreen)
# Out:
# Welcome to:
#
#   _____ _           _ _       _               _____                           _
#  |  __ \ |         | (_)     | |             |  __ \                         | |
#  | |  \/ | __ _  __| |_  __ _| |_ ___  _ __  | |  \/ __ _ _ __ ___   ___  ___| |
#  | | __| |/ _` |/ _` | |/ _` | __/ _ \| '__| | | __ / _` | '_ ` _ \ / _ \/ __| |
#  | |_\ \ | (_| | (_| | | (_| | || (_) | |    | |_\ \ (_| | | | | | |  __/\__ \_|
#   \____/_|\__,_|\__,_|_|\__,_|\__\___/|_|     \____/\__,_|_| |_| |_|\___||___/(_)
# <>:4: SyntaxWarning: invalid escape sequence '\ '
# <>:4: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/2d/yt4_w6zn5pbfjg_jx5sdmm180000gn/T/ipykernel_20626/4115848486.py:4: SyntaxWarning: invalid escape sequence '\ '
#   titleScreen = "Welcome to:\n\

# %% [markdown]
# # Character creation

# %%
characters = {
    "Fighter": [],
    "Mage": [],
    "Monk": [],
    "Citizen": []
}

def create_character(class_name, name):
    if class_name in characters:
        class_stats = {
            "Fighter": {"hp": 100, "mp": 50, "strength": 10, "agility": 5},
            "Mage": {"hp": 80, "mp": 100, "strength": 5, "agility": 8},
            "Monk": {"hp": 90, "mp": 60, "strength": 8, "agility": 10},
            "Citizen": {"hp": 120, "mp": 90, "strength": 10, "agility": 5}
        }
        character = {"name": name, "level": 1}
        character.update(class_stats[class_name])
        characters[class_name].append(character)
        print(f"{name} the {class_name} has been created!")
    else:
        print("Invalid character class.")

def main():
    print("Welcome to the character creation system!")
    print("Available character classes:")
    for class_name in characters:
        print("-", class_name)
    
    class_name = input("Choose a character class: ")
    if class_name in characters:
        name = input("Enter character name: ")
        create_character(class_name, name)
    else:
        print("Invalid character class.")

# %%
def roll_stats(num_stats=5, num_sides=20):
    stats = {}
    for i in range(1, num_stats + 1):
        stat = random.randint(1, num_sides) 
        stats[f"Roll {i}"] = stat
    return stats

print(stats)

# Generate a set of 5 stats (20-sided dice)
stats = roll_stats()
print("Character Stats:")
for roll, value in stats.items():
    print(f"{roll}: {value}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       5         stats[f"Roll {i}"] = stat
#       6     return stats
# ----> 8 print(stats)
#      10 # Generate a set of 5 stats (20-sided dice)
#      11 stats = roll_stats()
#
# NameError: name 'stats' is not defined

# %%
diceGraphic = "\n\
   ^\n\
 /_|_\\\n\
|/{roll:2d}\ |\n\
 \ | / \n\
   v"

def roll_stats(num_stats=5, num_sides=20):
    stats = {}
    for i in range(1, num_stats + 1):
        stat = random.randint(1, num_sides)
        stats[f"Roll {i}"] = stat
    return stats

# Generate a set of 5 stats (20-sided dice)
stats = roll_stats()
print("Character Stats:")
for roll, value in stats.items():
    print(f"{roll}:")
    print(diceGraphic.format(roll=value))
# Out:
# Character Stats:
# Roll 1:
#
#    ^
#  /_|_\
# |/11\ |
#  \ | /
#    v
# Roll 2:
#
#    ^
#  /_|_\
# |/ 2\ |
#  \ | /
#    v
# Roll 3:
#
#    ^
#  /_|_\
# |/ 8\ |
#  \ | /
#    v
# Roll 4:
#
#    ^
#  /_|_\
# |/ 3\ |
#  \ | /
#    v
# Roll 5:
#
#    ^
#  /_|_\
# |/10\ |
#  \ | /
#    v

# %%
print("\n\
        _-_.  \n\
     _-',^. `-_.  \n\
 ._-' ,'   `.   `-_  \n\
!`-_._________`-':::  \n\
!   /\        /\::::  \n\
;  /  \      /..\:::  \n\
! /    \    /....\::  \n\
# !/      \  /......\:  \n\
;--.___. \/_.__.--;;   \n\
 '-_    `:!;;;;;;;'  \n\
    `-_, :!;;;''  \n\
        `-!'    \n")
# Out:
#         _-_.
#      _-',^. `-_.
#  ._-' ,'   `.   `-_
# !`-_._________`-':::
# !   /\        /\::::
# ;  /  \      /..\:::
# ! /    \    /....\::
# !/      \  /......\:
# ;--.___. \/_.__.--;;
#  '-_    `:!;;;;;;;'
#     `-_, :!;;;''
#         `-!'

# %%
# fighter = '''\n\
#           @@   @@   @@@@@@@@@@@@@@@@@@@@  \n\          
#        -=-++==-++-=-++++++++++++++++++++-= \n\       
#        @@+--@@+--#@@--------------------+@@  \n\     
#     +@@--+@@-----------------------@@@@@@@@@@   \n\  
#     +@@--------------------------------------+@@  \n\
#        +++------------------------------+++++.    \n\
#        @@+------------------------------+@@@@     \n\
#     +@@------------------------------------@@     \n\
#     +@@--+@@--    -=@@@@@--------------------+@@  \n\
#     +@@--+@@--   .=+@@@%%---------------======##  \n\
#     +@@--+@@--+@@@@@@@   ---------------+@@@@     \n\
#        @@   @@:  %@@     -----     .-------@@     \n\
#             @@-  %@@        --     .----+**       \n\
#             @@-  %@@        --     .----+@@       \n\
#           @@@@-               .----@@@@@@@@       \n\
#        @@   --              @@@@+-----   --@@     \n\
#        *#   --              @@##+-----   --**     \n\
#     +@@-------+@@        @@@@@=--------------+@@  \n\
#        @@+----+@@@@@@@@@@--+@@=--------------+@@  \n\
#      +=   -----==@@@@@+==---==#%         %%%%     \n\
#     +@@   -------%@@@@=-------@@         @@@@     \n\
#     +@@     @@*------------      @@=--     @@     \n\
#     +@@-----   --%@@@@=--          .----   @@     \n\
#                +++++++=--          :----   @@     \n\
#   @@        @@@@@=-------        ----------@@     \n\
#   @@        @@@@@=------------@@@@@@@@@@@@@       \n\
#     :@@@@@@@     +@#----------@@                  \n\
#     +@@@@@@@     *@@----------@@                  \n\
#                  *@@             @@               \n\
#                  *@@------------+@@               \n\
#                  *@@------------+@@               \n\
#                  *@@------------+@@               \n\
#                  *@@------------+@@               \n\
#                @@=--------------+@@               \n\
#                ++================++               \n\
#                  *@@@@@@@@@@@@@@  \n\ 
# '''

fighter = '''
          @@   @@   @@@@@@@@@@@@@@@@@@@@  
       -=-++==-++-=-++++++++++++++++++++-= 
       @@+--@@+--#@@--------------------+@@  
    +@@--+@@-----------------------@@@@@@@@@@   
    +@@--------------------------------------+@@  
       +++------------------------------+++++.    
       @@+------------------------------+@@@@     
    +@@------------------------------------@@     
    +@@--+@@--    -=@@@@@--------------------+@@  
    +@@--+@@--   .=+@@@%%---------------======##  
    +@@--+@@--+@@@@@@@   ---------------+@@@@     
       @@   @@:  %@@     -----     .-------@@     
            @@-  %@@        --     .----+**       
            @@-  %@@        --     .----+@@       
          @@@@-               .----@@@@@@@@       
       @@   --              @@@@+-----   --@@     
       *#   --              @@##+-----   --**     
    +@@-------+@@        @@@@@=--------------+@@  
       @@+----+@@@@@@@@@@--+@@=--------------+@@  
     +=   -----==@@@@@+==---==#%         %%%%     
    +@@   -------%@@@@=-------@@         @@@@     
    +@@     @@*------------      @@=--     @@     
    +@@-----   --%@@@@=--          .----   @@     
               +++++++=--          :----   @@     
  @@        @@@@@=-------        ----------@@     
  @@        @@@@@=------------@@@@@@@@@@@@@       
    :@@@@@@@     +@#----------@@                  
    +@@@@@@@     *@@----------@@                  
                 *@@             @@               
                 *@@------------+@@               
                 *@@------------+@@               
                 *@@------------+@@               
                 *@@------------+@@               
               @@=--------------+@@               
               ++================++               
                 *@@@@@@@@@@@@@@  
'''

print(fighter)
# Out:
#           @@   @@   @@@@@@@@@@@@@@@@@@@@
#        -=-++==-++-=-++++++++++++++++++++-=
#        @@+--@@+--#@@--------------------+@@
#     +@@--+@@-----------------------@@@@@@@@@@
#     +@@--------------------------------------+@@
#        +++------------------------------+++++.
#        @@+------------------------------+@@@@
#     +@@------------------------------------@@
#     +@@--+@@--    -=@@@@@--------------------+@@
#     +@@--+@@--   .=+@@@%%---------------======##
#     +@@--+@@--+@@@@@@@   ---------------+@@@@
#        @@   @@:  %@@     -----     .-------@@
#             @@-  %@@        --     .----+**
#             @@-  %@@        --     .----+@@
#           @@@@-               .----@@@@@@@@
#        @@   --              @@@@+-----   --@@
#        *#   --              @@##+-----   --**
#     +@@-------+@@        @@@@@=--------------+@@
#        @@+----+@@@@@@@@@@--+@@=--------------+@@
#      +=   -----==@@@@@+==---==#%         %%%%
#     +@@   -------%@@@@=-------@@         @@@@
#     +@@     @@*------------      @@=--     @@
#     +@@-----   --%@@@@=--          .----   @@
#                +++++++=--          :----   @@
#   @@        @@@@@=-------        ----------@@
#   @@        @@@@@=------------@@@@@@@@@@@@@
#     :@@@@@@@     +@#----------@@
#     +@@@@@@@     *@@----------@@
#                  *@@             @@
#                  *@@------------+@@
#                  *@@------------+@@
#                  *@@------------+@@
#                  *@@------------+@@
#                @@=--------------+@@
#                ++================++
#                  *@@@@@@@@@@@@@@

# %%
monk = '''
                      @@@@@@@@@@@@@@@@@@@
   The              @@%%%%%%%%%%%%%%%%%%@@
     Monk          @@#++++++++++++++++++@@@
                 @@+++++++++++++++++++++++*@@
               @@#*#************************@@
               @@*+++++++++++++++++++++++++*@@@
           @@%+++++++++++++++++++++++++++++++%@@
           @@%++*++--+++*++++*++++*++*++*+*++%@@
           @@%++*++--+++*++++*++++*++*++*+*++%@@
           @@%+++++==+=====+++++=====+=====++%@@
           @@%++++*@@@@@@@@--=+++++++++++++++%@@
            @@***+*@@@@@@@@=-+++++*++*++*+*++%@@
           @@@@@*++--%@@=----=+++++++++++++++%@@
              @@@@@--%@@=----=+++++++++++++++%@@
       @@@@@@@%%%%%--#%%=--=-==+++*++*++*+*++%@@
      @@++*++*--+==-------------+++++++++++==%@@@
      @@--=--*+++=+----------*@@---++++++==--+--@@
      @@--=--*+++=+===--=--#####+=+++*+++=+--+--###@@
      @@--=--*+++=====-----@@#--=====+===----+--=--@@
      @@++*++*+++====%@@@@@--========+==++++++--=--@@
       @@@@@@@@@%%%==****+*+=+==*+*++*==+====*==+--@@
                @@@==+==---===--++++++-------+++=--@@
                 @@==+=====--------+++++=----+--+++@@
                 @@==+==+=+=-=----=++*++=-=--*++@@@@
                 @@==+=====--------+++++=----+++@@
                 @@@@@@@@@@@@#--++++++----=@@@@@
                 @@==+==@@@+=+=++=+==+==+=+@@
                 @@==+==@@@==+====+==+==+=+@@
                 @@==+==@@@==========+==@@@
                   @@*===============+==@@
                   @@#+++++++++++++++*++@@
                   @@*===============*@@@
                     @@+============*@@
                   @@%%+++++++++++++#@@
                   @@*===============*@@
'''
